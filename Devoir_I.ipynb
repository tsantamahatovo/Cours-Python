# %%
#Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
main_path="C:/Users/tsant/Downloads"
cars_path=main_path + "/used_cars_data.csv"
df=pd.read_csv(cars_path, sep=",")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 main_path="C:/Users/tsant/Downloads"
#       2 cars_path=main_path + "/used_cars_data.csv"
# ----> 3 df=pd.read_csv(cars_path, sep=",")
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\io\parsers\readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\io\parsers\readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:217, in CParserWrapper.read(self, nrows)
#     215     chunks = self._reader.read_low_memory(nrows)
#     216     # destructive to chunks
# --> 217     data = _concatenate_chunks(chunks, self.names)
#     218 else:
#     219     data = self._reader.read(nrows)
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:359, in _concatenate_chunks(chunks, column_names)
#     357     result[name] = union_categoricals(arrs, sort_categories=False)
#     358 else:
# --> 359     result[name] = concat_compat(arrs)
#     360     if len(non_cat_dtypes) > 1 and result[name].dtype == np.dtype(object):
#     361         warning_columns.append(column_names[name])
#
# File ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\core\dtypes\concat.py:78, in concat_compat(to_concat, axis, ea_compat_axis)
#      76 if isinstance(obj, np.ndarray):
#      77     to_concat_arrs = cast("Sequence[np.ndarray]", to_concat)
# ---> 78     return np.concatenate(to_concat_arrs, axis=axis)
#      80 to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#      81 if ea_compat_axis:
#      82     # We have 1D objects, that don't support axis keyword
#
# KeyboardInterrupt:

# %%
################################################################################################
# FILTRES POUR HOMOGENEISER ET FIABILISER LES DONNEES
################################################################################################
df = df[df["bed"].isna()]
df = df[df["cabin"].isna()]
df = df[df["frame_damaged"] != True]
df = df[df["has_accidents"] != True]
df = df[df["isCab"] != True]
df = df[~df["main_picture_url"].isna()]
df = df[(df["owner_count"].isna()) | (df["owner_count"] == 1)]
df = df[df["salvage"] != True]
df = df[df["theft_title"] != True]
df = df[df["daysonmarket"] < 365]

df = df.drop(["bed", "bed_height", "cabin", "city", "dealer_zip",
              "description", "exterior_color", "has_accidents", "interior_color",
              "isCab", "frame_damaged", "latitude", "longitude", "main_picture_url", "owner_count",
              "is_certified", "is_cpo", "salvage", "savings_amount", "seller_rating", "sp_id", "theft_title",
              "vehicle_damage_category"], axis=1)

# %% [markdown]
# SUPPRESSION DE 50% DU DATAFRAME

# %%
used_cars_data_shorter=df.sample(frac=0.5,random_state=42)
csv_path = main_path + "/used_cars_data_shorter.csv"
df.to_csv(csv_path, index=False)

# %% [markdown]
# SEPARATION ENTRE TRAIN ET TEST

# %%
cars1=pd.read_csv(r'C:\Users\tsant\Downloads\used_cars_data_shorter.csv')
SEED = 32
df_train, df_test = train_test_split(cars1, test_size=0.2, random_state=SEED)

# %%
df_train.info()
df_train.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1451463 entries, 725752 to 10967
# Data columns (total 43 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   vin                   1451463 non-null  str
#  1   back_legroom          1377195 non-null  str
#  2   bed_length            204220 non-null   str
#  3   body_type             1443908 non-null  str
#  4   city_fuel_economy     1233026 non-null  float64
#  5   combine_fuel_economy  0 non-null        float64
#  6   daysonmarket          1451463 non-null  int64
#  7   engine_cylinders      1405284 non-null  str
#  8   engine_displacement   1366463 non-null  float64
#  9   engine_type           1405284 non-null  str
#  10  fleet                 541522 non-null   object
#  11  franchise_dealer      1451463 non-null  bool
#  12  franchise_make        1322853 non-null  str
#  13  front_legroom         1377195 non-null  str
#  14  fuel_tank_volume      1377195 non-null  str
#  15  fuel_type             1416074 non-null  str
#  16  height                1377195 non-null  str
#  17  highway_fuel_economy  1233026 non-null  float64
#  18  horsepower            1366463 non-null  float64
#  19  is_new                1451463 non-null  bool
#  20  is_oemcpo             72790 non-null    object
#  21  length                1377195 non-null  str
#  22  listed_date           1451463 non-null  str
#  23  listing_color         1451463 non-null  str
#  24  listing_id            1451463 non-null  int64
#  25  major_options         1362269 non-null  str
#  26  make_name             1451463 non-null  str
#  27  maximum_seating       1377195 non-null  str
#  28  mileage               1377496 non-null  float64
#  29  model_name            1451463 non-null  str
#  30  power                 1191399 non-null  str
#  31  price                 1451463 non-null  float64
#  32  sp_name               1451463 non-null  str
#  33  torque                1175278 non-null  str
#  34  transmission          1423332 non-null  str
#  35  transmission_display  1423332 non-null  str
#  36  trimId                1396365 non-null  str
#  37  trim_name             1396285 non-null  str
#  38  wheel_system          1379781 non-null  str
#  39  wheel_system_display  1379781 non-null  str
#  40  wheelbase             1377195 non-null  str
#  41  width                 1377195 non-null  str
#  42  year                  1451463 non-null  int64
# dtypes: bool(2), float64(7), int64(3), object(2), str(29)
# memory usage: 467.9+ MB
#                        vin back_legroom bed_length        body_type  \
# 725752   5FNYF6H21MB006293      38.4 in        NaN  SUV / Crossover
# 1602288  3N1CP5BV2LL488229      33.2 in        NaN  SUV / Crossover
# 860720   JN8AT2MT6KW253789      37.9 in        NaN  SUV / Crossover
# 1569424  JHMCR6F55HC007317      38.5 in        NaN            Sedan
# 912623   5YFEPMAE9MP154754      34.8 in        NaN            Sedan
#
#          city_fuel_economy  combine_fuel_economy  daysonmarket  \
# 725752                19.0                   NaN            54
# 1602288               31.0                   NaN           253
# 860720                26.0                   NaN            10
# 1569424               49.0                   NaN            20
# 912623                30.0                   NaN             0
#
#         engine_cylinders  engine_displacement engine_type  ...  \
# 725752                V6               3500.0          V6  ...
# 1602288               I4               1600.0          I4  ...
# 860720                I4               2500.0          I4  ...
# 1569424        I4 Hybrid               2000.0   I4 Hybrid  ...
# 912623                I4               1800.0          I4  ...
#
#                         torque  transmission  \
# 725752   262 lb-ft @ 4,700 RPM             A
# 1602288  114 lb-ft @ 4,000 RPM           CVT
# 860720   175 lb-ft @ 4,400 RPM           CVT
# 1569424                    NaN           CVT
# 912623                     NaN           CVT
#
#                        transmission_display  trimId trim_name wheel_system  \
# 725752                            Automatic  t93929    SE AWD          AWD
# 1602288  Continuously Variable Transmission  t90148     S FWD          FWD
# 860720   Continuously Variable Transmission  t83705    SV FWD          FWD
# 1569424  Continuously Variable Transmission  t67707      EX-L          FWD
# 912623   Continuously Variable Transmission  t92966    LE FWD          FWD
#
#         wheel_system_display  wheelbase    width  year
# 725752       All-Wheel Drive     111 in  78.6 in  2021
# 1602288    Front-Wheel Drive   103.1 in  69.3 in  2020
# 860720     Front-Wheel Drive   106.5 in  72.4 in  2019
# 1569424    Front-Wheel Drive   109.3 in  72.8 in  2017
# 912623     Front-Wheel Drive   106.3 in  70.1 in  2021
#
# [5 rows x 43 columns]

# %% [markdown]
# SUPPRESSION DE CERTAINES COLONNES

# %%
df_train.isna().mean()*100
# Out:
# vin                       0.000000
# back_legroom              5.116768
# bed_length               85.930058
# body_type                 0.520509
# city_fuel_economy        15.049436
# combine_fuel_economy    100.000000
# daysonmarket              0.000000
# engine_cylinders          3.181549
# engine_displacement       5.856160
# engine_type               3.181549
# fleet                    62.691298
# franchise_dealer          0.000000
# franchise_make            8.860715
# front_legroom             5.116768
# fuel_tank_volume          5.116768
# fuel_type                 2.438161
# height                    5.116768
# highway_fuel_economy     15.049436
# horsepower                5.856160
# is_new                    0.000000
# is_oemcpo                94.985060
# length                    5.116768
# listed_date               0.000000
# listing_color             0.000000
# listing_id                0.000000
# major_options             6.145110
# make_name                 0.000000
# maximum_seating           5.116768
# mileage                   5.096031
# model_name                0.000000
# power                    17.917370
# price                     0.000000
# sp_name                   0.000000
# torque                   19.028043
# transmission              1.938113
# transmission_display      1.938113
# trimId                    3.796032
# trim_name                 3.801544
# wheel_system              4.938603
# wheel_system_display      4.938603
# wheelbase                 5.116768
# width                     5.116768
# year                      0.000000
# dtype: float64

# %%
#colonnes avec bcp de VM
variables=['bed_length','combine_fuel_economy','fleet','is_oemcpo']
df_train=df_train.drop(variables,axis=1)
df_test=df_test.drop(variables,axis=1)

# %% [markdown]
# ANALYSE EXPLORATOIRE

# %% [markdown]
# VARIABLES NUMERIQUES

# %%
#VARIABLES NUMERIQUES
varnum=['city_fuel_economy','daysonmarket','engine_displacement','highway_fuel_economy','horsepower','mileage','price','year']
df_train[varnum].describe()
df_train[varnum].describe()
# Out:
#        city_fuel_economy  daysonmarket  engine_displacement  \
# count       1.233026e+06  1.451463e+06         1.366463e+06
# mean        2.336350e+01  7.679651e+01         2.845424e+03
# std         9.420365e+00  8.562134e+01         1.301812e+03
# min         9.000000e+00  0.000000e+00         7.000000e+02
# 25%         1.800000e+01  1.800000e+01         2.000000e+03
# 50%         2.200000e+01  4.100000e+01         2.500000e+03
# 75%         2.600000e+01  9.400000e+01         3.500000e+03
# max         1.270000e+02  3.640000e+02         8.400000e+03
#
#        highway_fuel_economy    horsepower       mileage         price  \
# count          1.233026e+06  1.366463e+06  1.377496e+06  1.451463e+06
# mean           2.996361e+01  2.461950e+02  1.509772e+04  3.325317e+04
# std            8.053004e+00  9.083701e+01  2.912545e+04  1.902906e+04
# min            1.100000e+01  5.500000e+01  0.000000e+00  2.990000e+02
# 25%            2.500000e+01  1.740000e+02  5.000000e+00  2.198800e+04
# 50%            2.900000e+01  2.400000e+02  1.200000e+01  2.912000e+04
# 75%            3.300000e+01  3.000000e+02  2.219425e+04  4.094900e+04
# max            1.270000e+02  9.490000e+02  1.225238e+06  2.749950e+06
#
#                year
# count  1.451463e+06
# mean   2.018873e+03
# std    3.145131e+00
# min    1.915000e+03
# 25%    2.018000e+03
# 50%    2.020000e+03
# 75%    2.020000e+03
# max    2.021000e+03

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12, 12))

df_train.boxplot(column="city_fuel_economy", ax=axes[0,0])
df_train.boxplot(column="engine_displacement", ax=axes[0,1])
df_train.boxplot(column="highway_fuel_economy", ax=axes[1,0])
df_train.boxplot(column="horsepower", ax=axes[1,1])
df_train.boxplot(column="mileage", ax=axes[2,0])
# Out:
# <Axes: >

# %%
sns.heatmap(df_train[varnum].corr(),annot=True)
# Out:
# <Axes: >

# %%
#pour ces variables on va juste supprimer les lignes avec VM comme on a bcp d'observations
numvar=['engine_displacement','horsepower','mileage','city_fuel_economy','highway_fuel_economy']
df_train=df_train.dropna(subset=numvar)

# %%
#Dsitribution du prix ( la variable cible )
plt.figure(figsize=(10, 5))
sns.histplot(df_train['price'], kde=True, bins=50, color='blue')
plt.title('Distribution du Prix des Véhicules')
plt.xlabel('Prix ($)')
plt.ylabel('Fréquence')
plt.show()

# %%
#Analyse prix VS kilometrage
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_train, x='mileage', y='price', alpha=0.5)
plt.title('Relation entre le Kilométrage et le Prix')
plt.show()

# %%
#Analyse prix VS Année
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_train, x='year', y='price')
plt.xticks(rotation=45)
plt.title('Impact de l\'Année de Fabrication sur le Prix')
plt.show()

# %% [markdown]
# LES VARIABLES STR

# %%
strvar=['back_legroom','body_type','engine_cylinders','engine_type','front_legroom','fuel_tank_volume','fuel_type','height','length','major_options','maximum_seating','transmission','transmission_display','wheel_system','wheel_system_display','wheelbase','width']
df_train=df_train.dropna(subset=strvar)

# %%
strvar1=['franchise_make','power','torque']
df_train=df_train.dropna(subset=strvar1)

# %%
df_train.shape
# Out:
# (847335, 39)

# %%
#suppression de tout ce qui est identifiant
var=['vin','listing_id',]
df_train=df_train.drop(var,axis=1)

# %%
df_train.duplicated()
# Out:
# 725752     False
# 1602288    False
# 860720     False
# 763237     False
# 217553     False
#            ...
# 1466620    False
# 384403     False
# 655237     False
# 370219     False
# 10967      False
# Length: 847335, dtype: bool

# %%
#Analyse des var str
strcols = df_train.select_dtypes(include="object").columns

for col in strcols:
    n_unique = df_train[col].nunique()

    if n_unique > 1000:
        print(col, "->texte libre")

    elif n_unique > 50:
        print(col, "-> catégorielle haute cardinalité ")

    else:
        print(col, "-> catégorielle classique ")
# Out:
# C:\Users\tsant\AppData\Local\Temp\ipykernel_24860\3353849634.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   strcols = df_train.select_dtypes(include="object").columns
# back_legroom -> catégorielle haute cardinalité
# body_type -> catégorielle classique
# engine_cylinders -> catégorielle classique
# engine_type -> catégorielle classique
# franchise_make -> catégorielle classique
# front_legroom -> catégorielle haute cardinalité
# fuel_tank_volume -> catégorielle haute cardinalité
# fuel_type -> catégorielle classique
# height -> catégorielle haute cardinalité
# length -> catégorielle haute cardinalité
# listed_date -> catégorielle haute cardinalité
# listing_color -> catégorielle classique
# major_options ->texte libre
# make_name -> catégorielle haute cardinalité
# maximum_seating -> catégorielle classique
# model_name -> catégorielle haute cardinalité
# power ->texte libre
# sp_name ->texte libre
# torque ->texte libre
# transmission -> catégorielle classique
# transmission_display -> catégorielle classique
# trimId ->texte libre
# trim_name ->texte libre
# wheel_system -> catégorielle classique
# wheel_system_display -> catégorielle classique
# wheelbase -> catégorielle haute cardinalité
# width -> catégorielle haute cardinalité

# %%
#Analyse des var " texte libre"
df_train['sp_name'].value_counts()
# Out:
# sp_name
# Honda World                      1024
# Rock Honda                        802
# Jeff Wyler Eastgate Auto Mall     776
# Varsity Ford                      773
# Newton Nissan of Gallatin         695
#                                  ...
# Studebaker Buick GMC                1
# Struckman Ford Incorporated         1
# Rinke Chevrolet-Buick-GMC           1
# Sherman Cadillac                    1
# Tranquillity Chevrolet              1
# Name: count, Length: 12485, dtype: int64

# %%
df_train['power'].value_counts()
# Out:
# power
# 395 hp @ 5,750 RPM    38395
# 355 hp @ 5,600 RPM    27272
# 138 hp @ 4,900 RPM    26225
# 395 hp @ 5,600 RPM    22225
# 170 hp @ 6,000 RPM    20401
#                       ...
# 260 hp @ 5,300 RPM        1
# 268 hp @ 5,000 RPM        1
# 532 hp @ 7,250 RPM        1
# 156 hp @ 5,500 RPM        1
# 552 hp @ 8,700 RPM        1
# Name: count, Length: 1093, dtype: int64

# %%
df_train['trimId'].value_counts()
# Out:
# trimId
# t87739    13086
# t86414     9501
# t85772     6253
# t85771     5550
# t88293     5383
#           ...
# t53445        1
# t29483        1
# t30106        1
# t52191        1
# t67672        1
# Name: count, Length: 14847, dtype: int64

# %%
df_train['torque'].value_counts()
# Out:
# torque
# 400 lb-ft @ 4,500 RPM    34809
# 383 lb-ft @ 4,100 RPM    27272
# 148 lb-ft @ 200 RPM      25598
# 410 lb-ft @ 3,950 RPM    22068
# 132 lb-ft @ 4,500 RPM    21925
#                          ...
# 242 lb-ft @ 2,800 RPM        1
# 434 lb-ft @ 5,250 RPM        1
# 354 lb-ft @ 6,800 RPM        1
# 272 lb-ft @ 4,000 RPM        1
# 252 lb-ft @ 4,500 RPM        1
# Name: count, Length: 1089, dtype: int64

# %%
df_train['trim_name'].value_counts()
# Out:
# trim_name
# SE FWD                                   25435
# S FWD                                    18396
# XLT SuperCrew 4WD                        16732
# SV FWD                                   14110
# LX FWD                                   13614
#                                          ...
# LT Fleet FWD                                 1
# 100th Anniversary Special Edition RWD        1
# TDI Sport with Nav                           1
# Extended Wheelbase                           1
# 4 Dr SR5 V8 4WD                              1
# Name: count, Length: 3682, dtype: int64

# %%
df_train['major_options'].value_counts()
# Out:
# major_options
# ['Alloy Wheels', 'Bluetooth', 'Backup Camera']                                                                                                                                                                                                                                                                                                                                         25012
# ['Bluetooth', 'Backup Camera']                                                                                                                                                                                                                                                                                                                                                         11702
# ['Steel Wheels', 'Bluetooth', 'Backup Camera']                                                                                                                                                                                                                                                                                                                                          9807
# ['Bluetooth']                                                                                                                                                                                                                                                                                                                                                                           9199
# ['Adaptive Cruise Control', 'Alloy Wheels', 'Bluetooth', 'Backup Camera']                                                                                                                                                                                                                                                                                                               9084
#                                                                                                                                                                                                                                                                                                                                                                                        ...
# ['Navigation System', 'Suspension Package', 'Alloy Wheels', 'Appearance Package', 'Steel Wheels', 'Bluetooth', 'Backup Camera', 'Remote Start', 'Heated Seats', 'CarPlay']                                                                                                                                                                                                                 1
# ['Leather Seats', 'Customer Preferred Package', 'Navigation System', 'Adaptive Cruise Control', 'Alloy Wheels', 'Preferred Package', 'Technology Package', 'Blind Spot Monitoring', 'Parking Sensors', 'Premium Package', 'Heated Seats', 'Premium Sound Package', 'Android Auto', 'Quick Order Package', 'CarPlay', 'Bluetooth', 'Backup Camera', 'Remote Start', 'Sound Package']        1
# ['301A Mid Equipment Group', 'Navigation System', 'Alloy Wheels', 'Appearance Package']                                                                                                                                                                                                                                                                                                    1
# ['Leather Seats', 'Storage Package', 'Trailer Package', 'Heated Seats', 'Tow Package', 'Multi Zone Climate Control', 'LE Package', 'Bluetooth', 'Backup Camera', 'Remote Start', 'Off Road Package', 'Convenience Package', 'Z71 Package']                                                                                                                                                 1
# ['Power Package', 'Navigation System', 'Alloy Wheels', 'Bluetooth', 'Backup Camera', 'Premium Package']                                                                                                                                                                                                                                                                                    1
# Name: count, Length: 101441, dtype: int64

# %%
#suppression des variables qui seront difficile à encoder ( cardinalité élevée , texte libre bizarre et celles que je juge inutile et qui se repètent également
vars=['major_options','torque','power','trimId','trim_name','sp_name','transmission_display','wheel_system_display','franchise_make',]
df_train=df_train.drop(vars,axis=1)

# %%
#on peut encore enlever d'autres variables qui sont ambigues pour predire le prix
vars1=['listed_date','listing_color','daysonmarket',]
df_train=df_train.drop(vars1,axis=1)

# %%
#Certaines colonnes sont en str car elles ont des unités , il faut transformer en numeriques ( float)
cols_to_fix = ['fuel_tank_volume', 'height', 'length', 'width', 'wheelbase', 'back_legroom', 'front_legroom']

for col in cols_to_fix:
    # On extrait le nombre (incluant le point décimal) et on convertit en float
    df_train[col] = df_train[col].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
#Cas particulier pour engine cyclinders qui contient  du texte comme V6 , L4
# On ne garde que les chiffres de la colonne cylindres
df_train['engine_cylinders'] = df_train['engine_cylinders'].str.extract(r'(\d+)').astype(float)

# %%
#après transformation certaines colonnes sont vides car n'ont peut être pas contenu des nombres
print(df_train[cols_to_fix].isnull().sum())
# Out:
# fuel_tank_volume       54
# height                 40
# length                 40
# width                  40
# wheelbase              40
# back_legroom        12807
# front_legroom        4000
# dtype: int64

# %%
#On va remplir les vides pour faciliter le travail
#Pour savoir si on choisi la mediane ou la moyenne , on va observer les outliars
# On crée une grille de graphiques
cols=['fuel_tank_volume', 'height', 'length', 'width', 'wheelbase', 'back_legroom']
plt.figure(figsize=(15, 10))

for i, col in enumerate(cols):
    plt.subplot(2, 3, i+1) # Crée une petite case pour chaque variable
    sns.boxplot(y=df_train[col], color="skyblue")

plt.tight_layout()
plt.show()

# %%
cols1=['front_legroom','engine_cylinders']
plt.figure(figsize=(8, 10)) # Plus haut que large pour du 2x1

for i, col in enumerate(cols1):
    # On ajoute i+1 comme 3ème argument
    plt.subplot(2, 1, i + 1)
    sns.boxplot(y=df_train[col], color="skyblue")

plt.tight_layout()
plt.show()

# %%
#On va remplacer les vides par la mediane comme il y a des outliers
# Pour chaque colonne, on remplace les NaN par la médiane de cette colonne
# Liste des colonnes numériques
cols_vides = [
    'city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders'
]

for col in cols_vides:
    median_value = df_train[col].median()
    df_train[col] = df_train[col].fillna(median_value)

# Vérification finale
print(df_train[cols_to_fix].isnull().sum())
# Out:
# fuel_tank_volume    0
# height              0
# length              0
# width               0
# wheelbase           0
# back_legroom        0
# front_legroom       0
# dtype: int64

# %% [markdown]
# CREATION DE VARIABLES

# %%
#Age de la voiture
# On calcule l'age pour le train et le test
# On utilise 2026 car c'est l'année actuelle
df_train['age'] = 2026 - df_train['year']
df_test['age'] = 2026 - df_test['year']

# Petite vérification visuelle des premières lignes
print(df_train[['year', 'age']].head())

#Relation entre l'Âge et le Prix
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_train, x='age', y='price', alpha=0.5)
plt.title("Relation entre l'Âge de la voiture et son Prix")
plt.xlabel("Âge (années)")
plt.ylabel("Prix ($)")
plt.show()
# Out:
#          year  age
# 725752   2021    5
# 1602288  2020    6
# 860720   2019    7
# 763237   2020    6
# 217553   2020    6

# %% [markdown]
# Standardisation

# %%
scaler=StandardScaler()
df_train[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']]=scaler.fit_transform(df_train[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']])

# %%
df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']]=scaler.transform(df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24860\683027044.py in ?()
#       1 df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
#       2     'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
# ----> 3     'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']]=scaler.transform(df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
#       4     'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
#       5     'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']])
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, copy)
#    1090         xp, _, X_device = get_namespace_and_device(X)
#    1091         check_is_fitted(self)
#    1092
#    1093         copy = copy if copy is not None else self.copy
# -> 1094         X = validate_data(
#    1095             self,
#    1096             X,
#    1097             reset=False,
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2898             out = y
#    2899         else:
#    2900             out = X, y
#    2901     elif not no_val_X and no_val_y:
# -> 2902         out = check_array(X, input_name="X", **check_params)
#    2903     elif no_val_X and not no_val_y:
#    2904         out = _check_y(y, **check_params)
#    2905     else:
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# ~\.virtualenvs\v-FynA-xga\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: '14 gal'

# %%
cols_unites = ['fuel_tank_volume', 'height', 'length', 'width', 'wheelbase', 'back_legroom', 'front_legroom']

for col in cols_unites:
    if col in df_test.columns:
        # On extrait le chiffre et on convertit en float
        df_test[col] = df_test[col].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)


#Suppression sécurisée des colonnes (si elles existent encore)
vars_a_supprimer = ['major_options', 'torque', 'power', 'trimId', 'trim_name',
                    'sp_name', 'transmission_display', 'wheel_system_display', 'franchise_make',
                    'listed_date', 'listing_color', 'daysonmarket', 'vin', 'listing_id']

df_test = df_test.drop(vars_a_supprimer, axis=1, errors='ignore')

#Remplissage des vides (Imputation) avec la médiane du TRAIN
# On définit les colonnes numériques qu'on veut scaler plus tard
cols_vides = [
    'city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom'
]

for col in cols_vides:
    if col in df_test.columns:
        median_value = df_train[col].median() # On prend la valeur du TRAIN
        df_test[col] = df_test[col].fillna(median_value)

# %%
if 'engine_cylinders' in df_test.columns:
    df_test['engine_cylinders'] = df_test['engine_cylinders'].astype(str).str.extract(r'(\d+)').astype(float)

# %%
df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']]=scaler.transform(df_test[['city_fuel_economy', 'engine_displacement', 'highway_fuel_economy',
    'horsepower', 'mileage', 'fuel_tank_volume', 'height', 'length',
    'width', 'wheelbase', 'back_legroom', 'front_legroom', 'engine_cylinders']])

# %% [markdown]
# ONEHOTENCODING

# %%
# On définit les colonnes à transformer
cols_a_encoder = ['body_type', 'fuel_type', 'make_name', 'transmission', 'wheel_system']

# 1. On applique get_dummies sur le TRAIN
df_train_final = pd.get_dummies(df_train, columns=cols_a_encoder)

# 2. On applique get_dummies sur le TEST
df_test_final = pd.get_dummies(df_test, columns=cols_a_encoder)

# L'alignement
# On s'assure que le test a les mêmes colonnes que le train
# Si une colonne manque dans le test, on la crée avec des 0
# Si le test a une colonne en trop, on l'enlève
df_test_final = df_test_final.reindex(columns=df_train_final.columns, fill_value=0)

# Vérification
print(f"Nombre de colonnes Train : {df_train_final.shape[1]}")
print(f"Nombre de colonnes Test  : {df_test_final.shape[1]}")
# Out:
# Nombre de colonnes Train : 152
# Nombre de colonnes Test  : 152
